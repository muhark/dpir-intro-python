# %% [markdown]
# # Twitter's Academic API
#
# Let's go through a quick demo of how to use Twitter's new Academic Track full archive search.

# %% [markdown]
# ## Step 0: Set-Up
#
# So far, I have obtained an academic track Twitter account, and put my credentials into my preferred location: `~/.cfg/twitter.yaml`. The file looks like this:
#
# ```{yaml}
# search_tweets_v2:
#   endpoint:  https://api.twitter.com/2/tweets/search/all
#   consumer_key: <CONSUMER_KEY>
#   consumer_secret: <CONSUMER_SECRET>
#   bearer_token: <BEARER_TOKEN>
# ```

# %% [markdown]
# If you are using colab, you will need to give colab some way of accessing the file.
#
# One solution is to put the credentials file in the root your google drive and then mount the corresponding drive with the following command:

# %%
from google.colab import drive
drive.mount('/content/drive')

# Requirements - use conda install if you have a local installation
# !pip install searchtweets-v2
# !pip install requests pyyaml

# %% [markdown]
# # Step 1: Setting up credentials
#
# The `searchtweets` library provides a convenience function
# for reading in the credentials and passing them on in a
# standardised format.

# %%
import searchtweets as tw

# If using colab, credentials might be at "/content/drive/.twitter_keys.yaml"
search_args = tw.load_credentials("~/.cfg/twitter.yaml",
                                     yaml_key="search_tweets_v2",
                                     env_overwrite=False)

# %% [markdown]
# ## Step 2: First Request
#
# This library contains two ways of making requests.
#
# I'll demonstrate the easier one first.
#
# Let's get some tweets about political science.

# %%
query = tw.gen_request_parameters('polisci', results_per_call=10)
print(query)
# Out:
# {"query": "polisci", "max_results": 10}

# %%
tweets = tw.collect_results(
    query=query,
    max_tweets=10,
    result_stream_args=search_args
)

# %% [markdown]
# ## Step 3: Parsing the Results
#
# Let's look at what the our results:

# %%
print(
    f"The function returns a {type(tweets)},",
    f"where each tweet is held in a {type(tweets[0])}.",
    f"The total number of objects is: {len(tweets)}",
    f"The first 10 have the following keys (attributes): {tweets[0].keys()}", 
    f"The last is a token for the next query, with the following keys:\n {tweets[-1].keys()}",
    sep="\n"
)
# Out:
# The function returns a <class 'list'>,
# where each tweet is held in a <class 'dict'>.
# The total number of objects is: 11
# The first 10 have the following keys (attributes): dict_keys(['id', 'text'])
# The last is a token for the next query, with the following keys:
#  dict_keys(['newest_id', 'oldest_id', 'result_count', 'next_token'])

# %%
for tweet in tweets[:-1]:
    print(f"{tweet['id']}\n\t{tweet['text']}")
# Out:
# 1369281707577335809
# 	@vsbc_ @californiadem20 it's not that it's impossible - there's plenty of polisci material that does. but it does become very hard even for political scientists, let alone for us, the riffraff.
# 1369279033192677377
# 	RT @CU_CDCC: Looking forward to this timely conversation, featuring @carleton_music @cu_polisci  @CU_History and @CBCAdrianH ! Don't forget…
# 1369278788970946564
# 	RT @CU_FASS: Thurs at 7, @carleton_music welcomes you to join Prof. James Deaville &amp; panelists Prof. Melissa Haussman (@cu_polisci), Prof.…
# 1369278577527685124
# 	RT @MYBISA: Who's registered for #BISA2021?
#
# With 3 days of panels/roundtables, 3 awesome keynotes and fringe events inc @BISAPGN's 'meet t…
# 1369277721931624452
# 	per the good folks at facebook, 10 years ago i got into a polisci phd program i was really excited about and i am so, so glad i didn't do it
# 1369277221777575936
# 	RT @CU_CDCC: Looking forward to this timely conversation, featuring @carleton_music @cu_polisci  @CU_History and @CBCAdrianH ! Don't forget…
# 1369276965623054338
# 	Looking forward to this timely conversation, featuring @carleton_music @cu_polisci  @CU_History and @CBCAdrianH ! Don't forget to register for Thursday evening's event: https://t.co/CxHol93Nms https://t.co/ONcBs65GKc
# 1369275642328530944
# 	RT @CU_FASS: Thurs at 7, @carleton_music welcomes you to join Prof. James Deaville &amp; panelists Prof. Melissa Haussman (@cu_polisci), Prof.…
# 1369274703811125251
# 	@chrishanretty “Studying pork” is a heading i never thought I’d read in a polisci article
# 1369274519479750658
# 	@polisci_1625 ちゃんとログインしてて偉いでしょ(*''▽'')ﾄﾞﾔﾌﾝｽｯ

# %% [markdown]
# ## Step 4: Customizing Queries
#
# References:
#
# - Documentation on `searchtweets.gen_request_parameters`
# - https://developer.twitter.com/en/docs/twitter-api/fields
# - List of all tweet.fields: https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/tweet

# %%
query = tw.gen_request_parameters(
    query = "#metoo (place_country:MX OR place_country:IN) -is:retweet -is:nullcast",
    results_per_call = 100,
    start_time = "2021-01-01", 
    end_time = "2021-01-31",
    tweet_fields = "id,created_at,text,author_id,context_annotations,entities"
)

# %% [markdown]
# `"#metoo (place_country:MX OR place_country:IN) -is:retweet -is:nullcast"`
#
# - `#metoo`: the query begins with the special hashtag operator. This will match tweets that contain the hashtag: #metoo. Note that this will not match the text “metoo”, or a longer hashtag “#metookutsu”
# - ` ` Spaces act as boolean AND operators.
# - `( )` brackets (parentheses) group operators together.
# - `place_country:MX` filters for tweets geo-tagged in Mexico. Note that the country names are written as two-letter ISO codes, and also that the vast majority of tweets will not have a country code, so adding this filter will also end up filtering out of tweets that were in fact tweeted in your country of interest.
# - `OR` a boolean OR operator.
# - `-is:retweet` removes all retweets; in other words, you only get “primary” tweets. The minus sign negates the following argument, so we are saying IS NOT RETWEET. As a researcher, this is an incredibly useful one.
# - `-is:nullcast` removes tweets created purely as promotions/ads.

# %%
rs = tw.ResultStream(
    request_parameters=query,
    max_results=100,
    max_pages=1,
    **search_args
)

# %%
custom_tweets = list(rs.stream())

# %% [markdown]
# ## Analyzing the extended output
#
# Here are some tricks we haven't looked at so far, such as set comprehension:

# %%
# Seeing the unique combinations of keys (attributes) of the tweet
{
    tuple(sorted(tweet)) for tweet in custom_tweets
}
# Out:
# {('author_id', 'context_annotations', 'created_at', 'entities', 'id', 'text'),
#  ('author_id', 'created_at', 'entities', 'id', 'text'),
#  ('newest_id', 'oldest_id', 'result_count')}

# %%
# We can put these things in a pandas dataframe!
import pandas as pd

df = pd.DataFrame(custom_tweets[:-1])
df
# Out:
#               author_id                   id  \
# 0              25187518  1355630147639119876
# 1             337753203  1355600319116271619
# 2   1196830101511364608  1355204724375449601
# 3              50599372  1355119454342922240
# 4            3192855216  1354825131894349826
# 5   1353554760729649152  1354654438225399813
# 6            1140129434  1354599860272553984
# 7             206377381  1354311464903876609
# 8             159347165  1353746960147230723
# 9             252676883  1353691911689793536
# 10  1316283243528765442  1353590189424164864
# 11             16077725  1353393335717699585
# 12            235373903  1353206621200142336
# 13  1335032977403895811  1353141990385397760
# 14  1335032977403895811  1353137409563779073
# 15            107491054  1352983975455830016
# 16             60251761  1352833085323177984
# 17            128754730  1352805437192740864
# 18           2673327426  1352653389440577536
# 19  1342894542073155584  1352250169438289921
# 20           3169295430  1352247696434855939
# 21           1857558206  1352125161688862722
# 22            133120414  1351958225596256256
# 23            345829321  1351941008414666753
# 24  1340491046325604354  1351341304089776129
# 25  1063055236820942849  1351174061519466502
# 26  1306352219390750720  1351141627511898114
# 27             29184298  1350803652814880775
# 28   771315472671223808  1350780137319534593
# 29           3226665991  1350487372505505801
# 30            155688259  1350484273766264833
# 31             73341971  1350088022927179778
# 32            198819587  1349717689221095430
# 33            845482176  1349604181993144323
# 34           2673327426  1349243915560394754
# 35   854064936330330113  1349037504960204801
# 36           3301332866  1348991256190476290
# 37             67129678  1348805663640727552
# 38  1330165347308220419  1347769194998190080
# 39            822105926  1347665828674752513
# 40            277473815  1347495210360533001
# 41            277473815  1347494652409114628
# 42             37820141  1347222982196924418
# 43            101748079  1346739483933253633
# 44  1192128957392412672  1346705413132099584
# 45  1192128957392412672  1346448581545246720
# 46             80006297  1346266955271921666
# 47  1298143218324783105  1345717407910752256
# 48            280587873  1345487553084985350
# 49  1298143218324783105  1345268455474282497
# 50  1063055236820942849  1345099128074768384
# 51             77730690  1345030714417287170
#
#                                                  text  \
# 0   Ojalá estén tomando nota del #metoo que se le ...
# 1   #BB14 is promoting male sexual harassment . Sh...
# 2   @rohini_sgh @Dev_Fadnavis  Ha ha ha ha.  #Come...
# 3   I remember @factordaily was the only publicati...
# 4   @insia_dariwala @pragyavats @CSR_Environment @...
# 5   Happiness is something you want every second.....
# 6   Justicia, admiración y respeto para mi compañe...
# 7   One of the most disgusting things about the MJ...
# 8   https://t.co/X91gJXBsQa\n\n#metoomovement #MeT...
# 9                       @ExSecular #MeToo - MJ Akbar.
# 10  https://t.co/wAurrpz2oF\n\n#SexualHarassmentLa...
# 11  @lalochaps_ @PunisherIV Parece que te acosaba ...
# 12       El movimiento #MeToo ha vuelto. No es queja.
# 13  🟣Hablemos de VIOLENCIA SEXUAL CONTRA LAS MUJER...
# 14  🟣Esperemos que las Youtubers hagan uso de la #...
# 15  Una vez una persona me dijo “el #MeToo en la p...
# 16                                 @JainMaggii #MeToo
# 17  @addy_hdez @KattySims2 @Ricardo_Peralta @nathc...
# 18  Just In : @renusharma018 has taken her  compla...
# 19  The unfed mind devours itself.\n📷 Self-Portrai...
# 20  Ahora redimen a violadores.\nDónde están las F...
# 21  KelpHR applauds Truecaller for powerful initia...
# 22  @TimesNow @thenewshour You just can't save you...
# 23  Nikki you phattu .. 1st u said about #MeToo  a...
# 24  Hii guy's, \nGood morning, \nSorry #Nikkians\n...
# 25  "Be yourself, There's no one Better" 🤗\n\n#twi...
# 26  #tittok\n#MeToo\n#videogames\n\nhttps://t.co/9...
# 27                                @xyz15141514 #MeToo
# 28  #MeToo. \nJust a Second. It was Almost Instant...
# 29  Yo sería un cñoro intelectual, seductor, con c...
# 30  @RepChrisWelch @ChrisWelch_JD Nice.  #Illinois...
# 31          @drrakeshparikh #Metoo watching right now
# 32                            @DeepikaBhardwaj #metoo
# 33  ऐसे में तो @AayuSinghania पर बहुत से #MeToo लग...
# 34  Attention all.\n\nRamani failed to prove charg...
# 35  You are a dangerous person! Did you forget the...
# 36                     #metoo https://t.co/MaqTKXWzDJ
# 37  Ya se les acabó lo #MeToo contra Salgado Maced...
# 38  Iran criminalises sexual violence and harassme...
# 39  Les comparto mi columna:\nEstimado @mario_delg...
# 40  @TajinderBagga #MeToo officially exist in Cong...
# 41  Big expose by @SalmanNizami_ \n\n #MeToo offic...
# 42    @juagarci @reformagente ...es la del #metoo?...
# 43  @TheDailyPioneer @sharmarekha @NCWIndia Such a...
# 44  @AnumaVidisha @sjcbengaluru @abtaboonahi @CHIL...
# 45  @BrarIrina @SeemaHari @KSF_IN @mheduNIMHANS @g...
# 46  @IndianExpress Evidence would be scant and que...
# 47  #KamalHaasan says ‘dignity’ can protect women ...
# 48  #QuintanaRoo #PuertoAventiras @HardRock @HardR...
# 49  The Hindu does not seem to care about survivor...
# 50  Happy New Year To All! 💖\n2021 ✨💫⭐\n\n#twitter...
# 51  Appreciate fiercely independent journalists of...
#
#                   created_at  \
# 0   2021-01-30T21:33:08.000Z
# 1   2021-01-30T19:34:36.000Z
# 2   2021-01-29T17:22:39.000Z
# 3   2021-01-29T11:43:49.000Z
# 4   2021-01-28T16:14:17.000Z
# 5   2021-01-28T04:56:00.000Z
# 6   2021-01-28T01:19:08.000Z
# 7   2021-01-27T06:13:09.000Z
# 8   2021-01-25T16:50:01.000Z
# 9   2021-01-25T13:11:16.000Z
# 10  2021-01-25T06:27:04.000Z
# 11  2021-01-24T17:24:50.000Z
# 12  2021-01-24T05:02:54.000Z
# 13  2021-01-24T00:46:05.000Z
# 14  2021-01-24T00:27:53.000Z
# 15  2021-01-23T14:18:11.000Z
# 16  2021-01-23T04:18:36.000Z
# 17  2021-01-23T02:28:44.000Z
# 18  2021-01-22T16:24:33.000Z
# 19  2021-01-21T13:42:18.000Z
# 20  2021-01-21T13:32:29.000Z
# 21  2021-01-21T05:25:34.000Z
# 22  2021-01-20T18:22:13.000Z
# 23  2021-01-20T17:13:48.000Z
# 24  2021-01-19T01:30:48.000Z
# 25  2021-01-18T14:26:14.000Z
# 26  2021-01-18T12:17:21.000Z
# 27  2021-01-17T13:54:22.000Z
# 28  2021-01-17T12:20:55.000Z
# 29  2021-01-16T16:57:35.000Z
# 30  2021-01-16T16:45:16.000Z
# 31  2021-01-15T14:30:42.000Z
# 32  2021-01-14T13:59:08.000Z
# 33  2021-01-14T06:28:06.000Z
# 34  2021-01-13T06:36:31.000Z
# 35  2021-01-12T16:56:19.000Z
# 36  2021-01-12T13:52:33.000Z
# 37  2021-01-12T01:35:04.000Z
# 38  2021-01-09T04:56:31.000Z
# 39  2021-01-08T22:05:46.000Z
# 40  2021-01-08T10:47:48.000Z
# 41  2021-01-08T10:45:35.000Z
# 42  2021-01-07T16:46:03.000Z
# 43  2021-01-06T08:44:48.000Z
# 44  2021-01-06T06:29:25.000Z
# 45  2021-01-05T13:28:52.000Z
# 46  2021-01-05T01:27:09.000Z
# 47  2021-01-03T13:03:26.000Z
# 48  2021-01-02T21:50:05.000Z
# 49  2021-01-02T07:19:28.000Z
# 50  2021-01-01T20:06:37.000Z
# 51  2021-01-01T15:34:46.000Z
#
#                                              entities  \
# 0   {'hashtags': [{'start': 29, 'end': 35, 'tag': ...
# 1   {'mentions': [{'start': 220, 'end': 230, 'user...
# 2   {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 3   {'urls': [{'start': 241, 'end': 264, 'url': 'h...
# 4   {'urls': [{'start': 141, 'end': 164, 'url': 'h...
# 5   {'hashtags': [{'start': 95, 'end': 105, 'tag':...
# 6   {'urls': [{'start': 255, 'end': 278, 'url': 'h...
# 7   {'annotations': [{'start': 44, 'end': 51, 'pro...
# 8   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 9   {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 10  {'annotations': [{'start': 112, 'end': 116, 'p...
# 11  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 12  {'hashtags': [{'start': 14, 'end': 20, 'tag': ...
# 13  {'urls': [{'start': 270, 'end': 293, 'url': 'h...
# 14  {'urls': [{'start': 81, 'end': 104, 'url': 'ht...
# 15  {'mentions': [{'start': 261, 'end': 273, 'user...
# 16  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 17  {'annotations': [{'start': 230, 'end': 235, 'p...
# 18  {'annotations': [{'start': 205, 'end': 215, 'p...
# 19  {'urls': [{'start': 274, 'end': 297, 'url': 'h...
# 20  {'urls': [{'start': 124, 'end': 147, 'url': 'h...
# 21  {'annotations': [{'start': 0, 'end': 5, 'proba...
# 22  {'annotations': [{'start': 55, 'end': 60, 'pro...
# 23  {'annotations': [{'start': 0, 'end': 4, 'proba...
# 24  {'mentions': [{'start': 120, 'end': 133, 'user...
# 25  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 26  {'urls': [{'start': 28, 'end': 51, 'url': 'htt...
# 27  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 28  {'urls': [{'start': 48, 'end': 71, 'url': 'htt...
# 29  {'urls': [{'start': 139, 'end': 162, 'url': 'h...
# 30  {'urls': [{'start': 159, 'end': 182, 'url': 'h...
# 31  {'mentions': [{'start': 0, 'end': 15, 'usernam...
# 32  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 33  {'urls': [{'start': 101, 'end': 124, 'url': 'h...
# 34  {'annotations': [{'start': 78, 'end': 85, 'pro...
# 35  {'urls': [{'start': 79, 'end': 102, 'url': 'ht...
# 36  {'urls': [{'start': 7, 'end': 30, 'url': 'http...
# 37  {'annotations': [{'start': 33, 'end': 49, 'pro...
# 38  {'annotations': [{'start': 0, 'end': 3, 'proba...
# 39  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
# 40  {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 41  {'urls': [{'start': 87, 'end': 110, 'url': 'ht...
# 42  {'mentions': [{'start': 0, 'end': 9, 'username...
# 43  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 44  {'urls': [{'start': 141, 'end': 164, 'url': 'h...
# 45  {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 46  {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 47  {'urls': [{'start': 110, 'end': 133, 'url': 'h...
# 48  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 49  {'annotations': [{'start': 0, 'end': 8, 'proba...
# 50  {'urls': [{'start': 272, 'end': 295, 'url': 'h...
# 51  {'annotations': [{'start': 47, 'end': 54, 'pro...
#
#                                   context_annotations
# 0                                                 NaN
# 1   [{'domain': {'id': '3', 'name': 'TV Shows', 'd...
# 2   [{'domain': {'id': '10', 'name': 'Person', 'de...
# 3                                                 NaN
# 4   [{'domain': {'id': '10', 'name': 'Person', 'de...
# 5                                                 NaN
# 6   [{'domain': {'id': '3', 'name': 'TV Shows', 'd...
# 7   [{'domain': {'id': '10', 'name': 'Person', 'de...
# 8                                                 NaN
# 9   [{'domain': {'id': '10', 'name': 'Person', 'de...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [{'domain': {'id': '119', 'name': 'Holiday', '...
# 18                                                NaN
# 19  [{'domain': {'id': '46', 'name': 'Brand Catego...
# 20                                                NaN
# 21                                                NaN
# 22  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 23                                                NaN
# 24                                                NaN
# 25  [{'domain': {'id': '46', 'name': 'Brand Catego...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 35                                                NaN
# 36  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 37                                                NaN
# 38                                                NaN
# 39  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 40  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 41                                                NaN
# 42                                                NaN
# 43  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 44                                                NaN
# 45                                                NaN
# 46  [{'domain': {'id': '65', 'name': 'Interests an...
# 47  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 48  [{'domain': {'id': '55', 'name': 'Music Genre'...
# 49                                                NaN
# 50  [{'domain': {'id': '46', 'name': 'Brand Catego...
# 51                                                NaN

# %% [markdown]
# Two of the fields do not like being coerced to tabular structures. Here's a few tricks
# for unpacking them and breaking them down.
#
# The 'entities' field contains information such as hashtags, mentions, urls and so on:

# %%
{
    tuple(sorted(tweet['entities'])) for tweet in custom_tweets
        if 'entities' in tweet.keys()
}
# Out:
# {('annotations', 'hashtags'),
#  ('annotations', 'hashtags', 'mentions'),
#  ('annotations', 'hashtags', 'mentions', 'urls'),
#  ('annotations', 'hashtags', 'urls'),
#  ('hashtags',),
#  ('hashtags', 'mentions'),
#  ('hashtags', 'mentions', 'urls'),
#  ('hashtags', 'urls')}

# %%
[
    print(tweet['text'],  tweet['entities']['mentions'], '', sep='\n') for tweet in custom_tweets
        if 'entities' in tweet.keys() and 'mentions' in tweet['entities'].keys()
];
# Out:
# #BB14 is promoting male sexual harassment . Shocked to see #SalmanKhan calling #RakhiSawant ‘s harassment of #AbhinavSukla in BB house as entertainment. #HimToo is as serious issue as #MeToo #AbhinavShuklaDeservesBetter @ashukla09 - we are with you..
# [{'start': 220, 'end': 230, 'username': 'ashukla09'}]
#
# @rohini_sgh @Dev_Fadnavis  Ha ha ha ha.  #ComedyCircus by #BJPJokers. What is relevance here  original Dhongi and #Dimbendra. After this paid news ,people came to know that #Anna  was starting a #MeToo drama. BTW Ghantaa farak Nahi padta. #MVA is dealing farmer protest sensibly to keep peace
# [{'start': 0, 'end': 11, 'username': 'rohini_sgh'}, {'start': 12, 'end': 25, 'username': 'Dev_Fadnavis'}]
#
# I remember @factordaily was the only publication who consistently published and followed up on #MeToo before it blew up in2018 and they will forever have my respect for that. All the best folks! So excited to see you back and the new model! https://t.co/omS6mafU2Y
# [{'start': 11, 'end': 23, 'username': 'factordaily'}]
#
# @insia_dariwala @pragyavats @CSR_Environment @#metoo @ProfSonoraJha @BDUTT @TheRestlessQuil @MasalaBai @captraman @_AdilHussain @AzmiShabana https://t.co/3Q4Vdlk4di
# [{'start': 0, 'end': 15, 'username': 'insia_dariwala'}, {'start': 16, 'end': 27, 'username': 'pragyavats'}, {'start': 28, 'end': 44, 'username': 'CSR_Environment'}, {'start': 53, 'end': 67, 'username': 'ProfSonoraJha'}, {'start': 68, 'end': 74, 'username': 'BDUTT'}, {'start': 75, 'end': 91, 'username': 'TheRestlessQuil'}, {'start': 92, 'end': 102, 'username': 'MasalaBai'}, {'start': 103, 'end': 113, 'username': 'captraman'}, {'start': 114, 'end': 127, 'username': '_AdilHussain'}, {'start': 128, 'end': 140, 'username': 'AzmiShabana'}]
#
# Justicia, admiración y respeto para mi compañera de #doblaje @aworld2c por su valiente denuncia y determinación, muy a la altura de "mi carnala" #FionaGallagher @emmyrossum en #Shameless Repudio a su acosador.
# Te extrañaré #enelatril
# #MeToo @DoblajeWikia https://t.co/iJpfWujtUY
# [{'start': 61, 'end': 70, 'username': 'aworld2c'}, {'start': 161, 'end': 172, 'username': 'emmyrossum'}, {'start': 241, 'end': 254, 'username': 'DoblajeWikia'}]
#
# @ExSecular #MeToo - MJ Akbar.
# [{'start': 0, 'end': 10, 'username': 'ExSecular'}]
#
# @lalochaps_ @PunisherIV Parece que te acosaba #MeToo
# [{'start': 0, 'end': 11, 'username': 'lalochaps_'}, {'start': 12, 'end': 23, 'username': 'PunisherIV'}]
#
# Una vez una persona me dijo “el #MeToo en la peda no vale”...
#
# Me dieron ganas de gritarle todo lo que había callado por meses pero yo seguía confundido, avergonzado, culpable. Me tomó años afrontar.
#
# No es NO y que lxs niñxs aprendan desde chicxs.
#
# Yo te creo @nathcampost 💖
# [{'start': 261, 'end': 273, 'username': 'nathcampost'}]
#
# @JainMaggii #MeToo
# [{'start': 0, 'end': 11, 'username': 'JainMaggii'}]
#
# @addy_hdez @KattySims2 @Ricardo_Peralta @nathcampost Fui ofendida varias veces por comediantes públicamente ante miles de personas. Hice un video al respecto. Y en el standup se inició el movimiento #YaEstuvo que fue el #Metoo en México. ¿Tú crees que es casualidad que el gremio de comediantes pase por esto? #TodasSomosUna
# [{'start': 0, 'end': 10, 'username': 'addy_hdez'}, {'start': 11, 'end': 22, 'username': 'KattySims2'}, {'start': 23, 'end': 39, 'username': 'Ricardo_Peralta'}, {'start': 40, 'end': 52, 'username': 'nathcampost'}]
#
# Just In : @renusharma018 has taken her  complaint against @dhananjay_munde back !!
# No wonder another #FalseRape case filed to settle personal scores. #misuseofwomencentriclaws
# Shouldn't FAKE #MeToo LIAR,  Renu Sharma be arrested ?? @MumbaiPolice
# [{'start': 10, 'end': 24, 'username': 'renusharma018'}, {'start': 58, 'end': 74, 'username': 'dhananjay_munde'}, {'start': 232, 'end': 245, 'username': 'MumbaiPolice'}]
#
# @TimesNow @thenewshour You just can't save your #metoo Vineet
# [{'start': 0, 'end': 9, 'username': 'TimesNow'}, {'start': 10, 'end': 22, 'username': 'thenewshour'}]
#
# Hii guy's,
# Good morning,
# Sorry #Nikkians
# But it is wrong #NikkiTamboli don't pic old topic in fight....
#  #BiggBoss14
# @nikkitamboli raising #MeToo topic against @Devoleena_23 in her fight....
# That devo made a huge issue of it in her season....
# #NikkiTamboli
# #DevoleenaInBB14
# [{'start': 120, 'end': 133, 'username': 'nikkitamboli'}, {'start': 163, 'end': 176, 'username': 'Devoleena_23'}]
#
# @xyz15141514 #MeToo
# [{'start': 0, 'end': 12, 'username': 'xyz15141514'}]
#
# @RepChrisWelch @ChrisWelch_JD Nice.  #IllinoisDemocrats elect #domesticabuser as #ilspeaker   #metoo ? guess not.  #believewomen ? Guess not  @RepAnnWilliams
#
# https://t.co/rzFEy2JL6K
# [{'start': 0, 'end': 14, 'username': 'RepChrisWelch'}, {'start': 15, 'end': 29, 'username': 'ChrisWelch_JD'}, {'start': 142, 'end': 157, 'username': 'RepAnnWilliams'}]
#
# @drrakeshparikh #Metoo watching right now
# [{'start': 0, 'end': 15, 'username': 'drrakeshparikh'}]
#
# @DeepikaBhardwaj #metoo
# [{'start': 0, 'end': 16, 'username': 'DeepikaBhardwaj'}]
#
# ऐसे में तो @AayuSinghania पर बहुत से #MeToo लगेंगे!
# @SinghaniaVoice @tasveergrapher7 @made_up_of_ice https://t.co/PQbUTBeJlv
# [{'start': 11, 'end': 25, 'username': 'AayuSinghania'}, {'start': 52, 'end': 67, 'username': 'SinghaniaVoice'}, {'start': 68, 'end': 84, 'username': 'tasveergrapher7'}, {'start': 85, 'end': 100, 'username': 'made_up_of_ice'}]
#
# Les comparto mi columna:
# Estimado @mario_delgado ante tantas denuncias y voces en contra de @FelixSalMac seguirás con oídos sordos; quizás valdría la pena recordarte la campaña en tu alma mater de #MeToo
# Ojalá @CitlaHM pueda inferir en dar de baja a este candidato
#
# @diariobasta https://t.co/DwY3usa34j https://t.co/jTnFwjlELF
# [{'start': 34, 'end': 48, 'username': 'mario_delgado'}, {'start': 92, 'end': 104, 'username': 'FelixSalMac'}, {'start': 212, 'end': 220, 'username': 'CitlaHM'}, {'start': 268, 'end': 280, 'username': 'diariobasta'}]
#
# @TajinderBagga #MeToo officially exist in Congress  party Since 2013. 😷
# [{'start': 0, 'end': 14, 'username': 'TajinderBagga'}]
#
# Big expose by @SalmanNizami_
#
#  #MeToo officially exist in Congress  party Since 2013. https://t.co/JIbEdDf0F0
# [{'start': 14, 'end': 28, 'username': 'SalmanNizami_'}]
#
# @juagarci @reformagente ...es la del #metoo?...
# [{'start': 0, 'end': 9, 'username': 'juagarci'}, {'start': 10, 'end': 23, 'username': 'reformagente'}]
#
# @TheDailyPioneer @sharmarekha @NCWIndia Such a disturbing news, If we cannot keep our Women Safe, we cannot keep our Country safe. 48.9% population in this country comprises of Women. We beg Strict Law. #Nirbhaya happened and went, nothing has changed!!
# #womensafety #law #India @unwomenindia #MeToo
# [{'start': 0, 'end': 16, 'username': 'TheDailyPioneer'}, {'start': 17, 'end': 29, 'username': 'sharmarekha'}, {'start': 30, 'end': 39, 'username': 'NCWIndia'}, {'start': 280, 'end': 293, 'username': 'unwomenindia'}]
#
# @AnumaVidisha @sjcbengaluru @abtaboonahi @CHILDLINE1098 @MinistryWCD @NCWIndia #metoo @Pinklegal_in @VitalVoices @netshrink @mentalhealthind https://t.co/rsSdjaNbgZ
# [{'start': 0, 'end': 13, 'username': 'AnumaVidisha'}, {'start': 14, 'end': 27, 'username': 'sjcbengaluru'}, {'start': 28, 'end': 40, 'username': 'abtaboonahi'}, {'start': 41, 'end': 55, 'username': 'CHILDLINE1098'}, {'start': 56, 'end': 68, 'username': 'MinistryWCD'}, {'start': 69, 'end': 78, 'username': 'NCWIndia'}, {'start': 86, 'end': 99, 'username': 'Pinklegal_in'}, {'start': 100, 'end': 112, 'username': 'VitalVoices'}, {'start': 113, 'end': 123, 'username': 'netshrink'}, {'start': 124, 'end': 140, 'username': 'mentalhealthind'}]
#
# @BrarIrina @SeemaHari @KSF_IN @mheduNIMHANS @genderlogindia @swayamkolkata @mentalhealthind @netshrink #metoo @NyaayaIN @NirantarIndia https://t.co/9fFBiO9wdK
# [{'start': 0, 'end': 10, 'username': 'BrarIrina'}, {'start': 11, 'end': 21, 'username': 'SeemaHari'}, {'start': 22, 'end': 29, 'username': 'KSF_IN'}, {'start': 30, 'end': 43, 'username': 'mheduNIMHANS'}, {'start': 44, 'end': 59, 'username': 'genderlogindia'}, {'start': 60, 'end': 74, 'username': 'swayamkolkata'}, {'start': 75, 'end': 91, 'username': 'mentalhealthind'}, {'start': 92, 'end': 102, 'username': 'netshrink'}, {'start': 110, 'end': 119, 'username': 'NyaayaIN'}, {'start': 120, 'end': 134, 'username': 'NirantarIndia'}]
#
# @IndianExpress Evidence would be scant and questionable after 15 or more years of any crime. But courts must give credence to the voice of the tormented women who have come forward at risk to career and reputation. The ramifications of a wrong precedence here would be catastrophic.
# #MeToo
# [{'start': 0, 'end': 14, 'username': 'IndianExpress'}]
#
# #QuintanaRoo #PuertoAventiras @HardRock @HardRockHotels #HardRock #HardRockFeminicida @CarlosJoaquin @FGEQuintanaRoo @SedeturQROO #NiUnaMas #NiUnaMenos #MeToo #CuidarteEsCuidarnos #CuidemonosEntreTodos #CuidemosTodosDeTodos #Feminicidio #ViolenciaDeGenero #ViolenciaMachista #RT https://t.co/hJi4Sp0sar
# [{'start': 30, 'end': 39, 'username': 'HardRock'}, {'start': 40, 'end': 55, 'username': 'HardRockHotels'}, {'start': 86, 'end': 100, 'username': 'CarlosJoaquin'}, {'start': 101, 'end': 116, 'username': 'FGEQuintanaRoo'}, {'start': 117, 'end': 129, 'username': 'SedeturQROO'}]
#
# Appreciate fiercely independent journalists of Pakistan to take up this issue forward #MeToo
# @gabeenaa https://t.co/IhIouhxJrZ
# [{'start': 94, 'end': 103, 'username': 'gabeenaa'}]

# %% [markdown]
# The 'context_annotations' contains some very cool stuff.
#
# It's structured as a list of nested dictionaries however.

# %%
[
    print(tweet['text'], 
    [
        (t['domain']['name'], t['entity']['name']) for t in tweet['context_annotations']
    ], '', sep='\n') for tweet in custom_tweets
        if 'context_annotations' in tweet.keys()
];
# Out:
# #BB14 is promoting male sexual harassment . Shocked to see #SalmanKhan calling #RakhiSawant ‘s harassment of #AbhinavSukla in BB house as entertainment. #HimToo is as serious issue as #MeToo #AbhinavShuklaDeservesBetter @ashukla09 - we are with you..
# [('TV Shows', 'Big Brother UK'), ('Person', 'Abhinav Shukla'), ('Actor', 'Abhinav Shukla'), ('Person', 'Salman Khan'), ('Actor', 'Salman Khan')]
#
# @rohini_sgh @Dev_Fadnavis  Ha ha ha ha.  #ComedyCircus by #BJPJokers. What is relevance here  original Dhongi and #Dimbendra. After this paid news ,people came to know that #Anna  was starting a #MeToo drama. BTW Ghantaa farak Nahi padta. #MVA is dealing farmer protest sensibly to keep peace
# [('Person', 'Devendra Fadnavis'), ('Politician', 'Devendra Fadnavis')]
#
# @insia_dariwala @pragyavats @CSR_Environment @#metoo @ProfSonoraJha @BDUTT @TheRestlessQuil @MasalaBai @captraman @_AdilHussain @AzmiShabana https://t.co/3Q4Vdlk4di
# [('Person', 'Barkha Dutt'), ('Journalist', 'Barkha Dutt')]
#
# Justicia, admiración y respeto para mi compañera de #doblaje @aworld2c por su valiente denuncia y determinación, muy a la altura de "mi carnala" #FionaGallagher @emmyrossum en #Shameless Repudio a su acosador.
# Te extrañaré #enelatril
# #MeToo @DoblajeWikia https://t.co/iJpfWujtUY
# [('TV Shows', 'Shameless'), ('Person', 'Emmy Rossum'), ('Actor', 'Emmy Rossum')]
#
# One of the most disgusting things about the MJ Akbar Vs Priya Ramani defamation case is that a woman is the prosecutor here. #MeToo https://t.co/uflr9NpEed
# [('Person', 'M.J. Akbar'), ('Politician', 'M.J. Akbar')]
#
# @ExSecular #MeToo - MJ Akbar.
# [('Person', 'M.J. Akbar'), ('Politician', 'M.J. Akbar')]
#
# @addy_hdez @KattySims2 @Ricardo_Peralta @nathcampost Fui ofendida varias veces por comediantes públicamente ante miles de personas. Hice un video al respecto. Y en el standup se inició el movimiento #YaEstuvo que fue el #Metoo en México. ¿Tú crees que es casualidad que el gremio de comediantes pase por esto? #TodasSomosUna
# [('Holiday', 'Dia de la Independencia (Grito de Dolores) ')]
#
# The unfed mind devours itself.
# 📷 Self-Portrait❤️🔥
# #Twitter #Tweet #tweetfleet #tweegram #CuteTeens #cute #bellybotton #longhair #ootd #potd #crush #kbye #hello #foryou #keepsupporting #keepgoing #mood #positivevibes #goodvibes #hello #cuteness  #staysafe #stayathome #MeToo https://t.co/pvVGpbajfw
# [('Brand Category', 'Services'), ('Brand', 'Twitter'), ('Ongoing News Story', 'COVID-19'), ('Interests and Hobbies Vertical', 'Fashion'), ('Interests and Hobbies Vertical', 'Beauty'), ('Interests and Hobbies Category', 'Fashion Novelty'), ('Interests and Hobbies Category', 'Hair care'), ('Interests and Hobbies', 'Fashion Tags')]
#
# @TimesNow @thenewshour You just can't save your #metoo Vineet
# [('Brand Vertical', 'Entertainment'), ('Brand Category', 'TV/Movies Related'), ('Brand', 'TIMES NOW')]
#
# "Be yourself, There's no one Better" 🤗
#
# #twitter #antonypadikkala #love #smile #art #happy #like #follow #mood #metoo #me #I #myself #thankful #blessed #goal #photography #picoftheday #photooftheday #fashion #style #beautiful #place #travel #followers #likes #cool #beyourself https://t.co/z3ffLKTBRG
# [('Brand Category', 'Services'), ('Brand', 'Twitter'), ('Interests and Hobbies Vertical', 'Travel'), ('Interests and Hobbies Vertical', 'Home & family'), ('Interests and Hobbies', 'Photography'), ('Interests and Hobbies Vertical', 'Travel'), ('Interests and Hobbies Vertical', 'Fashion'), ('Interests and Hobbies Category', 'General Travel'), ('Interests and Hobbies Category', 'Travel novelty'), ('Interests and Hobbies Category', 'Fashion Novelty'), ('Interests and Hobbies', 'Travel Actions'), ('Interests and Hobbies', 'Travel photography'), ('Interests and Hobbies', 'Fashion Tags')]
#
# Attention all.
#
# Ramani failed to prove charges against  former union minister MJ Akbar !
# #MeTooLiar spotted
# #FalseRape  #FakeCases #MisuseOfRapeLaw
# She had made allegation of sexual misconduct against Akbar in the wake of #MeToo movement in 2018.
# [('Person', 'M.J. Akbar'), ('Politician', 'M.J. Akbar')]
#
# #metoo https://t.co/MaqTKXWzDJ
# [('Person', 'Narendra Modi'), ('Politician', 'Narendra Modi')]
#
# Les comparto mi columna:
# Estimado @mario_delgado ante tantas denuncias y voces en contra de @FelixSalMac seguirás con oídos sordos; quizás valdría la pena recordarte la campaña en tu alma mater de #MeToo
# Ojalá @CitlaHM pueda inferir en dar de baja a este candidato
#
# @diariobasta https://t.co/DwY3usa34j https://t.co/jTnFwjlELF
# [('Person', 'Enrique Peña Nieto'), ('Politician', 'Enrique Peña Nieto')]
#
# @TajinderBagga #MeToo officially exist in Congress  party Since 2013. 😷
# [('Person', 'Tajinder Pal Singh Bagga'), ('Politician', 'Tajinder Pal Singh Bagga')]
#
# @TheDailyPioneer @sharmarekha @NCWIndia Such a disturbing news, If we cannot keep our Women Safe, we cannot keep our Country safe. 48.9% population in this country comprises of Women. We beg Strict Law. #Nirbhaya happened and went, nothing has changed!!
# #womensafety #law #India @unwomenindia #MeToo
# [('Brand Vertical', 'Government/Education'), ('Brand Category', 'Non-profit'), ('Brand', 'United Nations'), ('Political Body', 'United Nations')]
#
# @IndianExpress Evidence would be scant and questionable after 15 or more years of any crime. But courts must give credence to the voice of the tormented women who have come forward at risk to career and reputation. The ramifications of a wrong precedence here would be catastrophic.
# #MeToo
# [('Interests and Hobbies Vertical', 'Careers')]
#
# #KamalHaasan says ‘dignity’ can protect women from violence, gets slammed #MeToo
# #SelfDefense #victimblaming
#
# https://t.co/9EQ6kJqB7D
# [('Person', 'Kamal Haasan'), ('Person', 'Kamal Haasan'), ('Politician', 'Kamal Haasan'), ('Actor', 'Kamal Haasan')]
#
# #QuintanaRoo #PuertoAventiras @HardRock @HardRockHotels #HardRock #HardRockFeminicida @CarlosJoaquin @FGEQuintanaRoo @SedeturQROO #NiUnaMas #NiUnaMenos #MeToo #CuidarteEsCuidarnos #CuidemonosEntreTodos #CuidemosTodosDeTodos #Feminicidio #ViolenciaDeGenero #ViolenciaMachista #RT https://t.co/hJi4Sp0sar
# [('Music Genre', 'Rock'), ('Music Genre', 'Classic rock'), ('Music Genre', 'Hard rock'), ('Ongoing News Story', 'COVID-19'), ('Brand Vertical', 'Dining'), ('Brand Category', 'Venue/Theatre'), ('Brand Category', 'Casual'), ('Brand', 'Hard Rock'), ('Interests and Hobbies Vertical', 'Food'), ('Interests and Hobbies Category', 'Cuisines'), ('Interests and Hobbies', 'American cuisine')]
#
# Happy New Year To All! 💖
# 2021 ✨💫⭐
#
# #twitter #antonypadikkala #love #smile #art #happy #like #follow #mood #metoo #me #I #myself #thankful #blessed #goal #photography #picoftheday #photooftheday #fashion #style #beautiful #place #travel #followers #likes #HappyNewYear2021 https://t.co/naE8ZIZgNb
# [('Brand Category', 'Services'), ('Brand', 'Twitter'), ('Interests and Hobbies Vertical', 'Travel'), ('Interests and Hobbies Vertical', 'Home & family'), ('Interests and Hobbies', 'Photography'), ('Holiday', 'New Years Eve'), ('Holiday', 'Happy New Year'), ('Interests and Hobbies Vertical', 'Travel'), ('Interests and Hobbies Vertical', 'Fashion'), ('Interests and Hobbies Category', 'General Travel'), ('Interests and Hobbies Category', 'Travel novelty'), ('Interests and Hobbies Category', 'Fashion Novelty'), ('Interests and Hobbies', 'Travel Actions'), ('Interests and Hobbies', 'Travel photography'), ('Interests and Hobbies', 'Fashion Tags'), ('Holiday', 'Happy New Year')]

# %%
# The same code, but easier to read (probably)

for tweet in custom_tweets:
    if 'context_annotations' in tweet.keys():
        print('TEXT:',
              tweet['text'],
              '\nNAMED ENTITIES:', sep='\n')
        for entry in tweet['context_annotations']:
            print(f"{entry['entity']['name']}: {entry['domain']['name']}")
        print('\n')
# Out:
# TEXT:
# #BB14 is promoting male sexual harassment . Shocked to see #SalmanKhan calling #RakhiSawant ‘s harassment of #AbhinavSukla in BB house as entertainment. #HimToo is as serious issue as #MeToo #AbhinavShuklaDeservesBetter @ashukla09 - we are with you..
#
# NAMED ENTITIES:
# Big Brother UK: TV Shows
# Abhinav Shukla: Person
# Abhinav Shukla: Actor
# Salman Khan: Person
# Salman Khan: Actor
#
#
# TEXT:
# @rohini_sgh @Dev_Fadnavis  Ha ha ha ha.  #ComedyCircus by #BJPJokers. What is relevance here  original Dhongi and #Dimbendra. After this paid news ,people came to know that #Anna  was starting a #MeToo drama. BTW Ghantaa farak Nahi padta. #MVA is dealing farmer protest sensibly to keep peace
#
# NAMED ENTITIES:
# Devendra Fadnavis: Person
# Devendra Fadnavis: Politician
#
#
# TEXT:
# @insia_dariwala @pragyavats @CSR_Environment @#metoo @ProfSonoraJha @BDUTT @TheRestlessQuil @MasalaBai @captraman @_AdilHussain @AzmiShabana https://t.co/3Q4Vdlk4di
#
# NAMED ENTITIES:
# Barkha Dutt: Person
# Barkha Dutt: Journalist
#
#
# TEXT:
# Justicia, admiración y respeto para mi compañera de #doblaje @aworld2c por su valiente denuncia y determinación, muy a la altura de "mi carnala" #FionaGallagher @emmyrossum en #Shameless Repudio a su acosador.
# Te extrañaré #enelatril
# #MeToo @DoblajeWikia https://t.co/iJpfWujtUY
#
# NAMED ENTITIES:
# Shameless: TV Shows
# Emmy Rossum: Person
# Emmy Rossum: Actor
#
#
# TEXT:
# One of the most disgusting things about the MJ Akbar Vs Priya Ramani defamation case is that a woman is the prosecutor here. #MeToo https://t.co/uflr9NpEed
#
# NAMED ENTITIES:
# M.J. Akbar: Person
# M.J. Akbar: Politician
#
#
# TEXT:
# @ExSecular #MeToo - MJ Akbar.
#
# NAMED ENTITIES:
# M.J. Akbar: Person
# M.J. Akbar: Politician
#
#
# TEXT:
# @addy_hdez @KattySims2 @Ricardo_Peralta @nathcampost Fui ofendida varias veces por comediantes públicamente ante miles de personas. Hice un video al respecto. Y en el standup se inició el movimiento #YaEstuvo que fue el #Metoo en México. ¿Tú crees que es casualidad que el gremio de comediantes pase por esto? #TodasSomosUna
#
# NAMED ENTITIES:
# Dia de la Independencia (Grito de Dolores) : Holiday
#
#
# TEXT:
# The unfed mind devours itself.
# 📷 Self-Portrait❤️🔥
# #Twitter #Tweet #tweetfleet #tweegram #CuteTeens #cute #bellybotton #longhair #ootd #potd #crush #kbye #hello #foryou #keepsupporting #keepgoing #mood #positivevibes #goodvibes #hello #cuteness  #staysafe #stayathome #MeToo https://t.co/pvVGpbajfw
#
# NAMED ENTITIES:
# Services: Brand Category
# Twitter: Brand
# COVID-19: Ongoing News Story
# Fashion: Interests and Hobbies Vertical
# Beauty: Interests and Hobbies Vertical
# Fashion Novelty: Interests and Hobbies Category
# Hair care: Interests and Hobbies Category
# Fashion Tags: Interests and Hobbies
#
#
# TEXT:
# @TimesNow @thenewshour You just can't save your #metoo Vineet
#
# NAMED ENTITIES:
# Entertainment: Brand Vertical
# TV/Movies Related: Brand Category
# TIMES NOW: Brand
#
#
# TEXT:
# "Be yourself, There's no one Better" 🤗
#
# #twitter #antonypadikkala #love #smile #art #happy #like #follow #mood #metoo #me #I #myself #thankful #blessed #goal #photography #picoftheday #photooftheday #fashion #style #beautiful #place #travel #followers #likes #cool #beyourself https://t.co/z3ffLKTBRG
#
# NAMED ENTITIES:
# Services: Brand Category
# Twitter: Brand
# Travel: Interests and Hobbies Vertical
# Home & family: Interests and Hobbies Vertical
# Photography: Interests and Hobbies
# Travel: Interests and Hobbies Vertical
# Fashion: Interests and Hobbies Vertical
# General Travel: Interests and Hobbies Category
# Travel novelty: Interests and Hobbies Category
# Fashion Novelty: Interests and Hobbies Category
# Travel Actions: Interests and Hobbies
# Travel photography: Interests and Hobbies
# Fashion Tags: Interests and Hobbies
#
#
# TEXT:
# Attention all.
#
# Ramani failed to prove charges against  former union minister MJ Akbar !
# #MeTooLiar spotted
# #FalseRape  #FakeCases #MisuseOfRapeLaw
# She had made allegation of sexual misconduct against Akbar in the wake of #MeToo movement in 2018.
#
# NAMED ENTITIES:
# M.J. Akbar: Person
# M.J. Akbar: Politician
#
#
# TEXT:
# #metoo https://t.co/MaqTKXWzDJ
#
# NAMED ENTITIES:
# Narendra Modi: Person
# Narendra Modi: Politician
#
#
# TEXT:
# Les comparto mi columna:
# Estimado @mario_delgado ante tantas denuncias y voces en contra de @FelixSalMac seguirás con oídos sordos; quizás valdría la pena recordarte la campaña en tu alma mater de #MeToo
# Ojalá @CitlaHM pueda inferir en dar de baja a este candidato
#
# @diariobasta https://t.co/DwY3usa34j https://t.co/jTnFwjlELF
#
# NAMED ENTITIES:
# Enrique Peña Nieto: Person
# Enrique Peña Nieto: Politician
#
#
# TEXT:
# @TajinderBagga #MeToo officially exist in Congress  party Since 2013. 😷
#
# NAMED ENTITIES:
# Tajinder Pal Singh Bagga: Person
# Tajinder Pal Singh Bagga: Politician
#
#
# TEXT:
# @TheDailyPioneer @sharmarekha @NCWIndia Such a disturbing news, If we cannot keep our Women Safe, we cannot keep our Country safe. 48.9% population in this country comprises of Women. We beg Strict Law. #Nirbhaya happened and went, nothing has changed!!
# #womensafety #law #India @unwomenindia #MeToo
#
# NAMED ENTITIES:
# Government/Education: Brand Vertical
# Non-profit: Brand Category
# United Nations: Brand
# United Nations: Political Body
#
#
# TEXT:
# @IndianExpress Evidence would be scant and questionable after 15 or more years of any crime. But courts must give credence to the voice of the tormented women who have come forward at risk to career and reputation. The ramifications of a wrong precedence here would be catastrophic.
# #MeToo
#
# NAMED ENTITIES:
# Careers: Interests and Hobbies Vertical
#
#
# TEXT:
# #KamalHaasan says ‘dignity’ can protect women from violence, gets slammed #MeToo
# #SelfDefense #victimblaming
#
# https://t.co/9EQ6kJqB7D
#
# NAMED ENTITIES:
# Kamal Haasan: Person
# Kamal Haasan: Person
# Kamal Haasan: Politician
# Kamal Haasan: Actor
#
#
# TEXT:
# #QuintanaRoo #PuertoAventiras @HardRock @HardRockHotels #HardRock #HardRockFeminicida @CarlosJoaquin @FGEQuintanaRoo @SedeturQROO #NiUnaMas #NiUnaMenos #MeToo #CuidarteEsCuidarnos #CuidemonosEntreTodos #CuidemosTodosDeTodos #Feminicidio #ViolenciaDeGenero #ViolenciaMachista #RT https://t.co/hJi4Sp0sar
#
# NAMED ENTITIES:
# Rock: Music Genre
# Classic rock: Music Genre
# Hard rock: Music Genre
# COVID-19: Ongoing News Story
# Dining: Brand Vertical
# Venue/Theatre: Brand Category
# Casual: Brand Category
# Hard Rock: Brand
# Food: Interests and Hobbies Vertical
# Cuisines: Interests and Hobbies Category
# American cuisine: Interests and Hobbies
#
#
# TEXT:
# Happy New Year To All! 💖
# 2021 ✨💫⭐
#
# #twitter #antonypadikkala #love #smile #art #happy #like #follow #mood #metoo #me #I #myself #thankful #blessed #goal #photography #picoftheday #photooftheday #fashion #style #beautiful #place #travel #followers #likes #HappyNewYear2021 https://t.co/naE8ZIZgNb
#
# NAMED ENTITIES:
# Services: Brand Category
# Twitter: Brand
# Travel: Interests and Hobbies Vertical
# Home & family: Interests and Hobbies Vertical
# Photography: Interests and Hobbies
# New Years Eve: Holiday
# Happy New Year: Holiday
# Travel: Interests and Hobbies Vertical
# Fashion: Interests and Hobbies Vertical
# General Travel: Interests and Hobbies Category
# Travel novelty: Interests and Hobbies Category
# Fashion Novelty: Interests and Hobbies Category
# Travel Actions: Interests and Hobbies
# Travel photography: Interests and Hobbies
# Fashion Tags: Interests and Hobbies
# Happy New Year: Holiday

# %% [markdown]
# ## Step 5: Saving tweets
#
# The tweets are json format, which we can save/read with the `json`
# library.

# %%
import json

def save_tweets(tweets, filename, mode='w'):
    with open(filename, mode) as fout:
       json.dump(tweets, fout)
    
def read_tweets(filename):
    with open(filename, 'r') as fin:
        tweets = json.load(fin)
    return tweets

save_tweets(custom_tweets, 'metoo_tweets.json')

# %%
read_tweets('metoo_tweets.json') == custom_tweets
# Out:
# True
